# %%
from langchain_huggingface import ChatHuggingFace, HuggingFacePipeline
import os
from huggingface_hub import InferenceClient
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
client = InferenceClient()

# %%
model_id = "meta-llama/Llama-3.1-8B-Instruct"

messages = [
    {"role": "user", "content": "The future of education is."}
]

result = client.chat_completion(
    model=model_id,
    messages=messages,
    max_tokens=50
)

# %%
result
# Out:
# ChatCompletionOutput(choices=[ChatCompletionOutputComplete(finish_reason='length', index=0, message=ChatCompletionOutputMessage(role='assistant', content='The future of education is exciting and rapidly evolving, driven by technological advancements, shifting societal needs, and innovative approaches to learning. Here are some key trends and predictions:\n\n1. **Personalized Learning**: With the help of AI, machine learning, and', reasoning=None, tool_call_id=None, tool_calls=None), logprobs=None)], created=1773394873, id='chatcmpl-71de562a-28c2-43b3-ae1e-a56aea6daf89', model='llama3.1-8b', system_fingerprint='fp_5198798116a66ebf301b', usage=ChatCompletionOutputUsage(completion_tokens=50, prompt_tokens=41, total_tokens=91, completion_tokens_details={'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0, 'reasoning_tokens': 0}, prompt_tokens_details={'cached_tokens': 0}), object='chat.completion', time_info={'queue_time': 0.000162721, 'prompt_time': 0.002633998, 'completion_time': 0.020172946, 'total_time': 0.024199962615966797, 'created': 1773394873.5846043})

# %%
result.choices[0].message
